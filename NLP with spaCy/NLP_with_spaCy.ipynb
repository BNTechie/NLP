# %%
# load the dataset
from datasets import load_dataset

# Load the IMDb dataset
dataset = load_dataset("imdb")

# %%
import spacy

# Import the displaCy library
from spacy import displacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Select a sample from the dataset
sample_text = dataset['train'][1]['text']

# Process the text with spaCy
doc = nlp(sample_text)

# %%
doc
# Out:
# "I Am Curious: Yellow" is a risible and pretentious steaming pile. It doesn't matter what one's political views are because this film can hardly be taken seriously on any level. As for the claim that frontal male nudity is an automatic NC-17, that isn't true. I've seen R-rated films with male nudity. Granted, they only offer some fleeting views, but where are the R-rated films with gaping vulvas and flapping labia? Nowhere, because they don't exist. The same goes for those crappy cable shows: schlongs swinging in the breeze but not a clitoris in sight. And those pretentious indie movies like The Brown Bunny, in which we're treated to the site of Vincent Gallo's throbbing johnson, but not a trace of pink visible on Chloe Sevigny. Before crying (or implying) "double-standard" in matters of nudity, the mentally obtuse should take into account one unavoidably obvious anatomical difference between men and women: there are no genitals on display when actresses appears nude, and the same cannot be said for a man. In fact, you generally won't see female genitals in an American film in anything short of porn or explicit erotica. This alleged double-standard is less a double standard than an admittedly depressing ability to come to terms culturally with the insides of women's bodies.

# %%
len(doc)
# Out:
# 261

# %% [markdown]
# **How many sentences are contained in the doc ?**

# %%
len([sent for sent in doc.sents])
# Out:
# 11

# %% [markdown]
# # tokenization and part-of-speech

# %% [markdown]
# For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.

# %%
for token in list(doc.sents)[2]:
    print(f'{token.text:{12}} {token.pos_:{6}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# As           ADP    IN     conjunction, subordinating or preposition
# for          ADP    IN     conjunction, subordinating or preposition
# the          DET    DT     determiner
# claim        NOUN   NN     noun, singular or mass
# that         SCONJ  IN     conjunction, subordinating or preposition
# frontal      ADJ    JJ     adjective (English), other noun-modifier (Chinese)
# male         PROPN  NNP    noun, proper singular
# nudity       NOUN   NN     noun, singular or mass
# is           AUX    VBZ    verb, 3rd person singular present
# an           DET    DT     determiner
# automatic    ADJ    JJ     adjective (English), other noun-modifier (Chinese)
# NC-17        NOUN   NN     noun, singular or mass
# ,            PUNCT  ,      punctuation mark, comma
# that         PRON   WDT    wh-determiner
# is           AUX    VBZ    verb, 3rd person singular present
# n't          PART   RB     adverb
# true         ADJ    JJ     adjective (English), other noun-modifier (Chinese)
# .            PUNCT  .      punctuation mark, sentence closer

# %%
# Print tokens and their POS tags
print("Tokenization and POS tagging:")
for token in doc:
    print(f"{token.text} -> {token.pos_}")
# Out:
# Tokenization and POS tagging:
# " -> PUNCT
# I -> PRON
# Am -> AUX
# Curious -> ADJ
# : -> PUNCT
# Yellow -> PROPN
# " -> PUNCT
# is -> AUX
# a -> DET
# risible -> ADJ
# and -> CCONJ
# pretentious -> ADJ
# steaming -> NOUN
# pile -> NOUN
# . -> PUNCT
# It -> PRON
# does -> AUX
# n't -> PART
# matter -> VERB
# what -> PRON
# one -> PRON
# 's -> PART
# political -> ADJ
# views -> NOUN
# are -> AUX
# because -> SCONJ
# this -> DET
# film -> NOUN
# can -> AUX
# hardly -> ADV
# be -> AUX
# taken -> VERB
# seriously -> ADV
# on -> ADP
# any -> DET
# level -> NOUN
# . -> PUNCT
# As -> ADP
# for -> ADP
# the -> DET
# claim -> NOUN
# that -> SCONJ
# frontal -> ADJ
# male -> PROPN
# nudity -> NOUN
# is -> AUX
# an -> DET
# automatic -> ADJ
# NC-17 -> NOUN
# , -> PUNCT
# that -> PRON
# is -> AUX
# n't -> PART
# true -> ADJ
# . -> PUNCT
# I -> PRON
# 've -> AUX
# seen -> VERB
# R -> NOUN
# - -> PUNCT
# rated -> VERB
# films -> NOUN
# with -> ADP
# male -> ADJ
# nudity -> NOUN
# . -> PUNCT
# Granted -> VERB
# , -> PUNCT
# they -> PRON
# only -> ADV
# offer -> VERB
# some -> DET
# fleeting -> ADJ
# views -> NOUN
# , -> PUNCT
# but -> CCONJ
# where -> SCONJ
# are -> AUX
# the -> DET
# R -> NOUN
# - -> PUNCT
# rated -> VERB
# films -> NOUN
# with -> ADP
# gaping -> VERB
# vulvas -> NOUN
# and -> CCONJ
# flapping -> VERB
# labia -> PROPN
# ? -> PUNCT
# Nowhere -> ADV
# , -> PUNCT
# because -> SCONJ
# they -> PRON
# do -> AUX
# n't -> PART
# exist -> VERB
# . -> PUNCT
# The -> DET
# same -> ADJ
# goes -> VERB
# for -> ADP
# those -> DET
# crappy -> ADJ
# cable -> NOUN
# shows -> NOUN
# : -> PUNCT
# schlongs -> NOUN
# swinging -> VERB
# in -> ADP
# the -> DET
# breeze -> NOUN
# but -> CCONJ
# not -> PART
# a -> DET
# clitoris -> NOUN
# in -> ADP
# sight -> NOUN
# . -> PUNCT
# And -> CCONJ
# those -> DET
# pretentious -> ADJ
# indie -> ADJ
# movies -> NOUN
# like -> ADP
# The -> DET
# Brown -> PROPN
# Bunny -> PROPN
# , -> PUNCT
# in -> ADP
# which -> PRON
# we -> PRON
# 're -> AUX
# treated -> VERB
# to -> ADP
# the -> DET
# site -> NOUN
# of -> ADP
# Vincent -> PROPN
# Gallo -> PROPN
# 's -> PART
# throbbing -> NOUN
# johnson -> PROPN
# , -> PUNCT
# but -> CCONJ
# not -> PART
# a -> DET
# trace -> NOUN
# of -> ADP
# pink -> ADJ
# visible -> ADJ
# on -> ADP
# Chloe -> PROPN
# Sevigny -> PROPN
# . -> PUNCT
# Before -> ADP
# crying -> VERB
# ( -> PUNCT
# or -> CCONJ
# implying -> VERB
# ) -> PUNCT
# " -> PUNCT
# double -> ADJ
# - -> PUNCT
# standard -> NOUN
# " -> PUNCT
# in -> ADP
# matters -> NOUN
# of -> ADP
# nudity -> NOUN
# , -> PUNCT
# the -> DET
# mentally -> ADV
# obtuse -> NOUN
# should -> AUX
# take -> VERB
# into -> ADP
# account -> NOUN
# one -> NUM
# unavoidably -> ADV
# obvious -> ADJ
# anatomical -> ADJ
# difference -> NOUN
# between -> ADP
# men -> NOUN
# and -> CCONJ
# women -> NOUN
# : -> PUNCT
# there -> PRON
# are -> VERB
# no -> DET
# genitals -> NOUN
# on -> ADP
# display -> NOUN
# when -> SCONJ
# actresses -> NOUN
# appears -> VERB
# nude -> ADJ
# , -> PUNCT
# and -> CCONJ
# the -> DET
# same -> ADJ
# can -> AUX
# not -> PART
# be -> AUX
# said -> VERB
# for -> ADP
# a -> DET
# man -> NOUN
# . -> PUNCT
# In -> ADP
# fact -> NOUN
# , -> PUNCT
# you -> PRON
# generally -> ADV
# wo -> AUX
# n't -> PART
# see -> VERB
# female -> ADJ
# genitals -> NOUN
# in -> ADP
# an -> DET
# American -> ADJ
# film -> NOUN
# in -> ADP
# anything -> PRON
# short -> ADJ
# of -> ADP
# porn -> NOUN
# or -> CCONJ
# explicit -> ADJ
# erotica -> NOUN
# . -> PUNCT
# This -> PRON
# alleged -> VERB
# double -> ADJ
# - -> PUNCT
# standard -> NOUN
# is -> AUX
# less -> ADJ
# a -> DET
# double -> ADJ
# standard -> NOUN
# than -> ADP
# an -> DET
# admittedly -> ADV
# depressing -> ADJ
# ability -> NOUN
# to -> PART
# come -> VERB
# to -> ADP
# terms -> NOUN
# culturally -> ADV
# with -> ADP
# the -> DET
# insides -> NOUN
# of -> ADP
# women -> NOUN
# 's -> PART
# bodies -> NOUN
# . -> PUNCT

# %% [markdown]
# # lemmatization
# Lemmatization is the process of reducing words to their base or root form. This is useful in tasks where you want to treat different forms of a word as the same word.

# %%
for token in doc:
    print(f"{token.text} -> {token.lemma_}")
# Out:
# " -> "
# I -> I
# Am -> be
# Curious -> curious
# : -> :
# Yellow -> Yellow
# " -> "
# is -> be
# a -> a
# risible -> risible
# and -> and
# pretentious -> pretentious
# steaming -> steaming
# pile -> pile
# . -> .
# It -> it
# does -> do
# n't -> not
# matter -> matter
# what -> what
# one -> one
# 's -> 's
# political -> political
# views -> view
# are -> be
# because -> because
# this -> this
# film -> film
# can -> can
# hardly -> hardly
# be -> be
# taken -> take
# seriously -> seriously
# on -> on
# any -> any
# level -> level
# . -> .
# As -> as
# for -> for
# the -> the
# claim -> claim
# that -> that
# frontal -> frontal
# male -> male
# nudity -> nudity
# is -> be
# an -> an
# automatic -> automatic
# NC-17 -> nc-17
# , -> ,
# that -> that
# is -> be
# n't -> not
# true -> true
# . -> .
# I -> I
# 've -> have
# seen -> see
# R -> r
# - -> -
# rated -> rate
# films -> film
# with -> with
# male -> male
# nudity -> nudity
# . -> .
# Granted -> grant
# , -> ,
# they -> they
# only -> only
# offer -> offer
# some -> some
# fleeting -> fleeting
# views -> view
# , -> ,
# but -> but
# where -> where
# are -> be
# the -> the
# R -> r
# - -> -
# rated -> rate
# films -> film
# with -> with
# gaping -> gape
# vulvas -> vulvas
# and -> and
# flapping -> flap
# labia -> labia
# ? -> ?
# Nowhere -> nowhere
# , -> ,
# because -> because
# they -> they
# do -> do
# n't -> not
# exist -> exist
# . -> .
# The -> the
# same -> same
# goes -> go
# for -> for
# those -> those
# crappy -> crappy
# cable -> cable
# shows -> show
# : -> :
# schlongs -> schlong
# swinging -> swinge
# in -> in
# the -> the
# breeze -> breeze
# but -> but
# not -> not
# a -> a
# clitoris -> clitoris
# in -> in
# sight -> sight
# . -> .
# And -> and
# those -> those
# pretentious -> pretentious
# indie -> indie
# movies -> movie
# like -> like
# The -> the
# Brown -> Brown
# Bunny -> Bunny
# , -> ,
# in -> in
# which -> which
# we -> we
# 're -> be
# treated -> treat
# to -> to
# the -> the
# site -> site
# of -> of
# Vincent -> Vincent
# Gallo -> Gallo
# 's -> 's
# throbbing -> throbbing
# johnson -> johnson
# , -> ,
# but -> but
# not -> not
# a -> a
# trace -> trace
# of -> of
# pink -> pink
# visible -> visible
# on -> on
# Chloe -> Chloe
# Sevigny -> Sevigny
# . -> .
# Before -> before
# crying -> cry
# ( -> (
# or -> or
# implying -> imply
# ) -> )
# " -> "
# double -> double
# - -> -
# standard -> standard
# " -> "
# in -> in
# matters -> matter
# of -> of
# nudity -> nudity
# , -> ,
# the -> the
# mentally -> mentally
# obtuse -> obtuse
# should -> should
# take -> take
# into -> into
# account -> account
# one -> one
# unavoidably -> unavoidably
# obvious -> obvious
# anatomical -> anatomical
# difference -> difference
# between -> between
# men -> man
# and -> and
# women -> woman
# : -> :
# there -> there
# are -> be
# no -> no
# genitals -> genital
# on -> on
# display -> display
# when -> when
# actresses -> actress
# appears -> appear
# nude -> nude
# , -> ,
# and -> and
# the -> the
# same -> same
# can -> can
# not -> not
# be -> be
# said -> say
# for -> for
# a -> a
# man -> man
# . -> .
# In -> in
# fact -> fact
# , -> ,
# you -> you
# generally -> generally
# wo -> will
# n't -> not
# see -> see
# female -> female
# genitals -> genital
# in -> in
# an -> an
# American -> american
# film -> film
# in -> in
# anything -> anything
# short -> short
# of -> of
# porn -> porn
# or -> or
# explicit -> explicit
# erotica -> erotica
# . -> .
# This -> this
# alleged -> allege
# double -> double
# - -> -
# standard -> standard
# is -> be
# less -> less
# a -> a
# double -> double
# standard -> standard
# than -> than
# an -> an
# admittedly -> admittedly
# depressing -> depressing
# ability -> ability
# to -> to
# come -> come
# to -> to
# terms -> term
# culturally -> culturally
# with -> with
# the -> the
# insides -> inside
# of -> of
# women -> woman
# 's -> 's
# bodies -> body
# . -> .

# %% [markdown]
# **Find the frequency of POS**

# %%
POS_counts = doc.count_by(spacy.attrs.POS)
for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{5}}: {v}')
# Out:
# 84. ADJ  : 28
# 85. ADP  : 29
# 86. ADV  : 9
# 87. AUX  : 17
# 89. CCONJ: 10
# 90. DET  : 23
# 92. NOUN : 49
# 93. NUM  : 1
# 94. PART : 11
# 95. PRON : 14
# 96. PROPN: 10
# 97. PUNCT: 33
# 98. SCONJ: 5
# 100. VERB : 22

# %% [markdown]
# **We can find what percentage of nouns are there?**

# %%
# the attribute ID for 'NOUN' is 92
percent = 100*POS_counts[92]/len(doc)
print(f'{POS_counts[92]}/{len(doc)} = {percent:{.4}}%')
# Out:
# 49/261 = 18.77%

# %%
# Visualize the dependency parse
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f0781cb779474222ac5b46351cbd8f01-0" class="displacy" width="40125" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Curious:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Yellow&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">risible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">pretentious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">steaming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">pile.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">matter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">political</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">views</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">hardly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">taken</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">seriously</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor"

# %% [markdown]
# # Morphological Analysis
# Description: Morphological analysis involves understanding the structure of words (like prefixes, suffixes, etc.). This includes analyzing grammatical features like tense, gender, and number.

# %%
for token in doc:
    print(f"{token.text} -> {token.morph}")
# Out:
# " -> PunctSide=Ini|PunctType=Quot
# I -> Case=Nom|Number=Sing|Person=1|PronType=Prs
# Am -> Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin
# Curious -> Degree=Pos
# : ->
# Yellow -> Number=Sing
# " -> PunctSide=Fin|PunctType=Quot
# is -> Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# a -> Definite=Ind|PronType=Art
# risible -> Degree=Pos
# and -> ConjType=Cmp
# pretentious -> Degree=Pos
# steaming -> Number=Sing
# pile -> Number=Sing
# . -> PunctType=Peri
# It -> Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# does -> Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# n't -> Polarity=Neg
# matter -> VerbForm=Inf
# what ->
# one -> PronType=Prs
# 's ->
# political -> Degree=Pos
# views -> Number=Plur
# are -> Mood=Ind|Tense=Pres|VerbForm=Fin
# because ->
# this -> Number=Sing|PronType=Dem
# film -> Number=Sing
# can -> VerbForm=Fin
# hardly ->
# be -> VerbForm=Inf
# taken -> Aspect=Perf|Tense=Past|VerbForm=Part
# seriously ->
# on ->
# any ->
# level -> Number=Sing
# . -> PunctType=Peri
# As ->
# for ->
# the -> Definite=Def|PronType=Art
# claim -> Number=Sing
# that ->
# frontal -> Degree=Pos
# male -> Number=Sing
# nudity -> Number=Sing
# is -> Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# an -> Definite=Ind|PronType=Art
# automatic -> Degree=Pos
# NC-17 -> Number=Sing
# , -> PunctType=Comm
# that -> PronType=Rel
# is -> Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# n't -> Polarity=Neg
# true -> Degree=Pos
# . -> PunctType=Peri
# I -> Case=Nom|Number=Sing|Person=1|PronType=Prs
# 've -> Mood=Ind|Tense=Pres|VerbForm=Fin
# seen -> Aspect=Perf|Tense=Past|VerbForm=Part
# R -> Number=Sing
# - -> PunctType=Dash
# rated -> Aspect=Perf|Tense=Past|VerbForm=Part
# films -> Number=Plur
# with ->
# male -> Degree=Pos
# nudity -> Number=Sing
# . -> PunctType=Peri
# Granted -> Aspect=Perf|Tense=Past|VerbForm=Part
# , -> PunctType=Comm
# they -> Case=Nom|Number=Plur|Person=3|PronType=Prs
# only ->
# offer -> Tense=Pres|VerbForm=Fin
# some ->
# fleeting -> Degree=Pos
# views -> Number=Plur
# , -> PunctType=Comm
# but -> ConjType=Cmp
# where ->
# are -> Mood=Ind|Tense=Pres|VerbForm=Fin
# the -> Definite=Def|PronType=Art
# R -> Number=Sing
# - -> PunctType=Dash
# rated -> Aspect=Perf|Tense=Past|VerbForm=Part
# films -> Number=Plur
# with ->
# gaping -> Aspect=Prog|Tense=Pres|VerbForm=Part
# vulvas -> Number=Sing
# and -> ConjType=Cmp
# flapping -> Aspect=Prog|Tense=Pres|VerbForm=Part
# labia -> Number=Sing
# ? -> PunctType=Peri
# Nowhere ->
# , -> PunctType=Comm
# because ->
# they -> Case=Nom|Number=Plur|Person=3|PronType=Prs
# do -> Mood=Ind|Tense=Pres|VerbForm=Fin
# n't -> Polarity=Neg
# exist -> VerbForm=Inf
# . -> PunctType=Peri
# The -> Definite=Def|PronType=Art
# same -> Degree=Pos
# goes -> Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# for ->
# those -> Number=Plur|PronType=Dem
# crappy -> Degree=Pos
# cable -> Number=Sing
# shows -> Number=Plur
# : ->
# schlongs -> Number=Plur
# swinging -> Aspect=Prog|Tense=Pres|VerbForm=Part
# in ->
# the -> Definite=Def|PronType=Art
# breeze -> Number=Sing
# but -> ConjType=Cmp
# not -> Polarity=Neg
# a -> Definite=Ind|PronType=Art
# clitoris -> Number=Sing
# in ->
# sight -> Number=Sing
# . -> PunctType=Peri
# And -> ConjType=Cmp
# those -> Number=Plur|PronType=Dem
# pretentious -> Degree=Pos
# indie -> Degree=Pos
# movies -> Number=Plur
# like ->
# The -> Definite=Def|PronType=Art
# Brown -> Number=Sing
# Bunny -> Number=Sing
# , -> PunctType=Comm
# in ->
# which ->
# we -> Case=Nom|Number=Plur|Person=1|PronType=Prs
# 're -> Mood=Ind|Tense=Pres|VerbForm=Fin
# treated -> Aspect=Perf|Tense=Past|VerbForm=Part
# to ->
# the -> Definite=Def|PronType=Art
# site -> Number=Sing
# of ->
# Vincent -> Number=Sing
# Gallo -> Number=Sing
# 's ->
# throbbing -> Number=Sing
# johnson -> Number=Sing
# , -> PunctType=Comm
# but -> ConjType=Cmp
# not -> Polarity=Neg
# a -> Definite=Ind|PronType=Art
# trace -> Number=Sing
# of ->
# pink -> Degree=Pos
# visible -> Degree=Pos
# on ->
# Chloe -> Number=Sing
# Sevigny -> Number=Sing
# . -> PunctType=Peri
# Before ->
# crying -> Aspect=Prog|Tense=Pres|VerbForm=Part
# ( -> PunctSide=Ini|PunctType=Brck
# or -> ConjType=Cmp
# implying -> Aspect=Prog|Tense=Pres|VerbForm=Part
# ) -> PunctSide=Fin|PunctType=Brck
# " -> PunctSide=Ini|PunctType=Quot
# double -> Degree=Pos
# - -> PunctType=Dash
# standard -> Number=Sing
# " -> PunctSide=Fin|PunctType=Quot
# in ->
# matters -> Number=Plur
# of ->
# nudity -> Number=Sing
# , -> PunctType=Comm
# the -> Definite=Def|PronType=Art
# mentally ->
# obtuse -> Number=Sing
# should -> VerbForm=Fin
# take -> VerbForm=Inf
# into ->
# account -> Number=Sing
# one -> NumType=Card
# unavoidably ->
# obvious -> Degree=Pos
# anatomical -> Degree=Pos
# difference -> Number=Sing
# between ->
# men -> Number=Plur
# and -> ConjType=Cmp
# women -> Number=Plur
# : ->
# there ->
# are -> Mood=Ind|Tense=Pres|VerbForm=Fin
# no ->
# genitals -> Number=Plur
# on ->
# display -> Number=Sing
# when ->
# actresses -> Number=Plur
# appears -> Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# nude -> Degree=Pos
# , -> PunctType=Comm
# and -> ConjType=Cmp
# the -> Definite=Def|PronType=Art
# same -> Degree=Pos
# can -> VerbForm=Fin
# not -> Polarity=Neg
# be -> VerbForm=Inf
# said -> Aspect=Perf|Tense=Past|VerbForm=Part
# for ->
# a -> Definite=Ind|PronType=Art
# man -> Number=Sing
# . -> PunctType=Peri
# In ->
# fact -> Number=Sing
# , -> PunctType=Comm
# you -> Case=Nom|Person=2|PronType=Prs
# generally ->
# wo -> VerbType=Mod
# n't -> Polarity=Neg
# see -> VerbForm=Inf
# female -> Degree=Pos
# genitals -> Number=Plur
# in ->
# an -> Definite=Ind|PronType=Art
# American -> Degree=Pos
# film -> Number=Sing
# in ->
# anything -> Number=Sing|PronType=Ind
# short -> Degree=Pos
# of ->
# porn -> Number=Sing
# or -> ConjType=Cmp
# explicit -> Degree=Pos
# erotica -> Number=Sing
# . -> PunctType=Peri
# This -> Number=Sing|PronType=Dem
# alleged -> Aspect=Perf|Tense=Past|VerbForm=Part
# double -> Degree=Pos
# - -> PunctType=Dash
# standard -> Number=Sing
# is -> Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# less -> Degree=Cmp
# a -> Definite=Ind|PronType=Art
# double -> Degree=Pos
# standard -> Number=Sing
# than ->
# an -> Definite=Ind|PronType=Art
# admittedly ->
# depressing -> Degree=Pos
# ability -> Number=Sing
# to ->
# come -> VerbForm=Inf
# to ->
# terms -> Number=Plur
# culturally ->
# with ->
# the -> Definite=Def|PronType=Art
# insides -> Number=Plur
# of ->
# women -> Number=Plur
# 's ->
# bodies -> Number=Plur
# . -> PunctType=Peri

# %% [markdown]
# # Named Entity Recognition (NER)

# %% [markdown]
# NER is the process of identifying named entities (e.g., people, organizations, locations) in text.

# %%
print("\nNamed Entity Recognition:")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Named Entity Recognition:
# I Am Curious: Yellow -> WORK_OF_ART
# The Brown Bunny -> FAC
# Vincent Gallo's -> PERSON
# johnson -> PERSON
# Chloe Sevigny -> PERSON
# American -> NORP

# %%
# Visualize named entities
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">&quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     I Am Curious: Yellow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot; is a risible and pretentious steaming pile. It doesn't matter what one's political views are because this film can hardly be taken seriously on any level. As for the claim that frontal male nudity is an automatic NC-17, that isn't true. I've seen R-rated films with male nudity. Granted, they only offer some fleeting views, but where are the R-rated films with gaping vulvas and flapping labia? Nowhere, because they don't exist. The same goes for those crappy cable shows: schlongs swinging in the breeze but not a clitoris in sight. And those pretentious indie movies like
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Brown Bunny
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , in which we're treated to the site of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vincent Gallo's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  throbbing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     johnson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , but not a trace of pink visible on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chloe Sevigny
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Before crying (or implying) &quot;double-standard&quot; in matters of nudity, the mentally obtuse should take into account one unavoidably obvious anatomical difference between men and women: there are no genitals on display when actresses appears nude, and the same cannot be said for a man. In fact, you generally won't see female genitals in an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  film in anything short of porn or explicit erotica. This alleged double-standard is less a double standard than an admittedly depressing ability to come to terms culturally with the insides of women's bodies.</div></span>

# %% [markdown]
# # Dependency Parsing
# Dependency parsing analyzes the grammatical structure of a sentence and establishes relationships between "head" words and words that modify those heads.

# %%
print("\nDependency Parsing:")
for token in doc:
    print(f"{token.text} -> {token.dep_} (Head: {token.head.text})")
# Out:
# Dependency Parsing:
# " -> punct (Head: is)
# I -> nsubj (Head: Am)
# Am -> ccomp (Head: is)
# Curious -> acomp (Head: Am)
# : -> punct (Head: Yellow)
# Yellow -> nsubj (Head: is)
# " -> punct (Head: Yellow)
# is -> ROOT (Head: is)
# a -> det (Head: pile)
# risible -> amod (Head: pile)
# and -> cc (Head: risible)
# pretentious -> conj (Head: risible)
# steaming -> compound (Head: pile)
# pile -> attr (Head: is)
# . -> punct (Head: is)
# It -> nsubj (Head: matter)
# does -> aux (Head: matter)
# n't -> neg (Head: matter)
# matter -> ROOT (Head: matter)
# what -> det (Head: views)
# one -> poss (Head: views)
# 's -> case (Head: one)
# political -> amod (Head: views)
# views -> nsubj (Head: are)
# are -> ccomp (Head: matter)
# because -> mark (Head: taken)
# this -> det (Head: film)
# film -> nsubjpass (Head: taken)
# can -> aux (Head: taken)
# hardly -> advmod (Head: taken)
# be -> auxpass (Head: taken)
# taken -> advcl (Head: are)
# seriously -> advmod (Head: taken)
# on -> prep (Head: taken)
# any -> det (Head: level)
# level -> pobj (Head: on)
# . -> punct (Head: are)
# As -> ROOT (Head: As)
# for -> prep (Head: As)
# the -> det (Head: claim)
# claim -> pobj (Head: for)
# that -> mark (Head: is)
# frontal -> amod (Head: nudity)
# male -> compound (Head: nudity)
# nudity -> nsubj (Head: is)
# is -> acl (Head: claim)
# an -> det (Head: NC-17)
# automatic -> amod (Head: NC-17)
# NC-17 -> attr (Head: is)
# , -> punct (Head: NC-17)
# that -> nsubj (Head: is)
# is -> relcl (Head: NC-17)
# n't -> neg (Head: is)
# true -> acomp (Head: is)
# . -> punct (Head: As)
# I -> nsubj (Head: seen)
# 've -> aux (Head: seen)
# seen -> ROOT (Head: seen)
# R -> npadvmod (Head: rated)
# - -> punct (Head: rated)
# rated -> amod (Head: films)
# films -> dobj (Head: seen)
# with -> prep (Head: films)
# male -> amod (Head: nudity)
# nudity -> pobj (Head: with)
# . -> punct (Head: seen)
# Granted -> advcl (Head: offer)
# , -> punct (Head: offer)
# they -> nsubj (Head: offer)
# only -> advmod (Head: offer)
# offer -> ROOT (Head: offer)
# some -> det (Head: views)
# fleeting -> amod (Head: views)
# views -> dobj (Head: offer)
# , -> punct (Head: offer)
# but -> cc (Head: offer)
# where -> advmod (Head: are)
# are -> conj (Head: offer)
# the -> det (Head: films)
# R -> npadvmod (Head: rated)
# - -> punct (Head: rated)
# rated -> amod (Head: films)
# films -> nsubj (Head: are)
# with -> prep (Head: films)
# gaping -> amod (Head: vulvas)
# vulvas -> pobj (Head: with)
# and -> cc (Head: vulvas)
# flapping -> amod (Head: labia)
# labia -> conj (Head: vulvas)
# ? -> punct (Head: offer)
# Nowhere -> advmod (Head: exist)
# , -> punct (Head: exist)
# because -> mark (Head: exist)
# they -> nsubj (Head: exist)
# do -> aux (Head: exist)
# n't -> neg (Head: exist)
# exist -> ROOT (Head: exist)
# . -> punct (Head: exist)
# The -> det (Head: same)
# same -> nsubj (Head: goes)
# goes -> ROOT (Head: goes)
# for -> prep (Head: goes)
# those -> det (Head: shows)
# crappy -> amod (Head: shows)
# cable -> compound (Head: shows)
# shows -> pobj (Head: for)
# : -> punct (Head: shows)
# schlongs -> dobj (Head: goes)
# swinging -> acl (Head: schlongs)
# in -> prep (Head: swinging)
# the -> det (Head: breeze)
# breeze -> pobj (Head: in)
# but -> cc (Head: schlongs)
# not -> neg (Head: clitoris)
# a -> det (Head: clitoris)
# clitoris -> conj (Head: schlongs)
# in -> prep (Head: clitoris)
# sight -> pobj (Head: in)
# . -> punct (Head: goes)
# And -> cc (Head: movies)
# those -> det (Head: movies)
# pretentious -> amod (Head: movies)
# indie -> amod (Head: movies)
# movies -> ROOT (Head: movies)
# like -> prep (Head: movies)
# The -> det (Head: Bunny)
# Brown -> compound (Head: Bunny)
# Bunny -> pobj (Head: like)
# , -> punct (Head: Bunny)
# in -> prep (Head: treated)
# which -> pobj (Head: in)
# we -> nsubjpass (Head: treated)
# 're -> auxpass (Head: treated)
# treated -> relcl (Head: Bunny)
# to -> prep (Head: treated)
# the -> det (Head: site)
# site -> pobj (Head: to)
# of -> prep (Head: site)
# Vincent -> compound (Head: Gallo)
# Gallo -> poss (Head: johnson)
# 's -> case (Head: Gallo)
# throbbing -> compound (Head: johnson)
# johnson -> pobj (Head: of)
# , -> punct (Head: site)
# but -> cc (Head: site)
# not -> neg (Head: trace)
# a -> det (Head: trace)
# trace -> conj (Head: site)
# of -> prep (Head: trace)
# pink -> advmod (Head: visible)
# visible -> pobj (Head: of)
# on -> prep (Head: visible)
# Chloe -> compound (Head: Sevigny)
# Sevigny -> pobj (Head: on)
# . -> punct (Head: movies)
# Before -> prep (Head: take)
# crying -> pcomp (Head: Before)
# ( -> punct (Head: crying)
# or -> cc (Head: crying)
# implying -> conj (Head: crying)
# ) -> punct (Head: implying)
# " -> punct (Head: standard)
# double -> amod (Head: standard)
# - -> punct (Head: standard)
# standard -> pobj (Head: Before)
# " -> punct (Head: standard)
# in -> prep (Head: standard)
# matters -> pobj (Head: in)
# of -> prep (Head: matters)
# nudity -> pobj (Head: of)
# , -> punct (Head: take)
# the -> det (Head: obtuse)
# mentally -> amod (Head: obtuse)
# obtuse -> nsubj (Head: take)
# should -> aux (Head: take)
# take -> ccomp (Head: are)
# into -> prep (Head: take)
# account -> pobj (Head: into)
# one -> nummod (Head: difference)
# unavoidably -> advmod (Head: obvious)
# obvious -> amod (Head: difference)
# anatomical -> amod (Head: difference)
# difference -> dobj (Head: take)
# between -> prep (Head: difference)
# men -> pobj (Head: between)
# and -> cc (Head: men)
# women -> conj (Head: men)
# : -> punct (Head: are)
# there -> expl (Head: are)
# are -> ROOT (Head: are)
# no -> det (Head: genitals)
# genitals -> attr (Head: are)
# on -> prep (Head: genitals)
# display -> pobj (Head: on)
# when -> advmod (Head: appears)
# actresses -> nsubj (Head: appears)
# appears -> advcl (Head: are)
# nude -> oprd (Head: appears)
# , -> punct (Head: are)
# and -> cc (Head: are)
# the -> det (Head: same)
# same -> nsubjpass (Head: said)
# can -> aux (Head: said)
# not -> neg (Head: said)
# be -> auxpass (Head: said)
# said -> conj (Head: are)
# for -> prep (Head: said)
# a -> det (Head: man)
# man -> pobj (Head: for)
# . -> punct (Head: said)
# In -> prep (Head: see)
# fact -> pobj (Head: In)
# , -> punct (Head: see)
# you -> nsubj (Head: see)
# generally -> advmod (Head: see)
# wo -> aux (Head: see)
# n't -> neg (Head: see)
# see -> ROOT (Head: see)
# female -> amod (Head: genitals)
# genitals -> dobj (Head: see)
# in -> prep (Head: see)
# an -> det (Head: film)
# American -> amod (Head: film)
# film -> pobj (Head: in)
# in -> prep (Head: see)
# anything -> pobj (Head: in)
# short -> amod (Head: anything)
# of -> prep (Head: short)
# porn -> pobj (Head: of)
# or -> cc (Head: porn)
# explicit -> amod (Head: erotica)
# erotica -> conj (Head: porn)
# . -> punct (Head: see)
# This -> nsubj (Head: alleged)
# alleged -> ROOT (Head: alleged)
# double -> amod (Head: standard)
# - -> punct (Head: standard)
# standard -> nsubj (Head: is)
# is -> ccomp (Head: alleged)
# less -> acomp (Head: is)
# a -> det (Head: standard)
# double -> amod (Head: standard)
# standard -> attr (Head: is)
# than -> prep (Head: standard)
# an -> det (Head: ability)
# admittedly -> advmod (Head: depressing)
# depressing -> amod (Head: ability)
# ability -> pobj (Head: than)
# to -> aux (Head: come)
# come -> acl (Head: ability)
# to -> prep (Head: come)
# terms -> pobj (Head: to)
# culturally -> advmod (Head: come)
# with -> prep (Head: come)
# the -> det (Head: insides)
# insides -> pobj (Head: with)
# of -> prep (Head: insides)
# women -> poss (Head: bodies)
# 's -> case (Head: women)
# bodies -> pobj (Head: of)
# . -> punct (Head: is)

# %% [markdown]
# **Display the Dependency Parse for the fourth sentence**

# %%
displacy.render(list(doc.sents)[3], style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c1e452dd3b7145fbb2e4d4c5ba6b59c7-0" class="displacy" width="1040" height="247.0" direction="ltr" style="max-width: none; height: 247.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">'ve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">seen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">R-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">rated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">films</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">male</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">nudity.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-0" stroke-width="2px" d="M70,112.0 C70,2.0 270.0,2.0 270.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,114.0 L62,102.0 78,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-1" stroke-width="2px" d="M180,112.0 C180,57.0 265.0,57.0 265.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,114.0 L172,102.0 188,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-2" stroke-width="2px" d="M400,112.0 C400,57.0 485.0,57.0 485.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,114.0 L392,102.0 408,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-3" stroke-width="2px" d="M510,112.0 C510,57.0 595.0,57.0 595.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510,114.0 L502,102.0 518,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-4" stroke-width="2px" d="M290,112.0 C290,2.0 600.0,2.0 600.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M600.0,114.0 L608.0,102.0 592.0,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-5" stroke-width="2px" d="M620,112.0 C620,57.0 705.0,57.0 705.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M705.0,114.0 L713.0,102.0 697.0,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-6" stroke-width="2px" d="M840,112.0 C840,57.0 925.0,57.0 925.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,114.0 L832,102.0 848,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-7" stroke-width="2px" d="M730,112.0 C730,2.0 930.0,2.0 930.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c1e452dd3b7145fbb2e4d4c5ba6b59c7-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M930.0,114.0 L938.0,102.0 922.0,102.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# # Sentence Segmentation
# Sentence segmentation divides the text into individual sentences.

# %%
print("\nSentence Segmentation:")
for sent in doc.sents:
    print(f"Sentence: {sent.text}")
# Out:
# Sentence Segmentation:
# Sentence: "I Am Curious: Yellow" is a risible and pretentious steaming pile.
# Sentence: It doesn't matter what one's political views are because this film can hardly be taken seriously on any level.
# Sentence: As for the claim that frontal male nudity is an automatic NC-17, that isn't true.
# Sentence: I've seen R-rated films with male nudity.
# Sentence: Granted, they only offer some fleeting views, but where are the R-rated films with gaping vulvas and flapping labia?
# Sentence: Nowhere, because they don't exist.
# Sentence: The same goes for those crappy cable shows: schlongs swinging in the breeze but not a clitoris in sight.
# Sentence: And those pretentious indie movies like The Brown Bunny, in which we're treated to the site of Vincent Gallo's throbbing johnson, but not a trace of pink visible on Chloe Sevigny.
# Sentence: Before crying (or implying) "double-standard" in matters of nudity, the mentally obtuse should take into account one unavoidably obvious anatomical difference between men and women: there are no genitals on display when actresses appears nude, and the same cannot be said for a man.
# Sentence: In fact, you generally won't see female genitals in an American film in anything short of porn or explicit erotica.
# Sentence: This alleged double-standard is less a double standard than an admittedly depressing ability to come to terms culturally with the insides of women's bodies.

# %% [markdown]
# # Text Similarity
# spaCy can be also  used to compare the similarity between texts, sentences, or individual tokens. This is useful in tasks like clustering, duplicate detection, or recommendation systems.

# %%
doc1 = nlp("I am a bit tired")
doc2 = nlp("I feel so ecstatic")
print(f"Similarity: {doc1.similarity(doc2)}")
# Out:
# Similarity: 0.5591253855795965
# /tmp/ipykernel_22135/2387317897.py:3: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(f"Similarity: {doc1.similarity(doc2)}")

# %%
displacy.render(doc, style="dep", jupyter=True, options={"compact": True, "bg": "#09a3d5", "color": "white", "font": "Source Sans Pro"})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2c5d0d520d6841cb8c6dd51f9bd3f9a7-0" class="displacy" width="34400" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Curious:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Yellow&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">risible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">pretentious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">steaming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">pile.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">matter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">political</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">views</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">hardly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">taken</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">seriously</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="current

# %%
## language detection

# %%
#from langdetect import detect
#text = "ami to make bhalobasi"
#language = detect(text) # Output: 'fr'
#print(f"The detected language is: {language}")

# %% [markdown]
# # Matcher

# %%
from spacy.matcher import Matcher

# %%
# Initialize the Matcher with the shared vocabulary
matcher = Matcher(nlp.vocab)

# Define a pattern to match adjectives followed by nouns (e.g., "great movie")
adj_noun_pattern = [{"POS": "ADJ"}, {"POS": "NOUN"}]
matcher.add("ADJ_NOUN_PATTERN", [adj_noun_pattern])

# Define a pattern to match monetary amounts (e.g., "$100 million")
money_pattern = [{"IS_CURRENCY": True}, {"LIKE_NUM": True}, {"LOWER": {"IN": ["million", "billion", "trillion"]}}]
matcher.add("MONEY_PATTERN", [money_pattern])

# %%
# Process a sample of text from the dataset
for i in range(7):  # Let's process the first 7 reviews
    text = dataset['train'][i]['text']
    doc = nlp(text)
    
    # Apply the matcher to the document
    matches = matcher(doc)
    
    print(f"Review {i + 1}:")
    for match_id, start, end in matches:
        matched_span = doc[start:end]
        print(f"  Matched span: {matched_span.text}")
    print("\n")
# Out:
# Review 1:
#   Matched span: Swedish drama
#   Matched span: average Swede
#   Matched span: political issues
#   Matched span: ordinary denizens
#   Matched span: major staple
#   Matched span: Swedish cinema
#   Matched span: old boy
#   Matched span: artistic purposes
#   Matched span: pornographic theaters
#   Matched span: good film
#   Matched span: Swedish cinema
#
#
# Review 2:
#   Matched span: pretentious steaming
#   Matched span: political views
#   Matched span: automatic NC-17
#   Matched span: male nudity
#   Matched span: fleeting views
#   Matched span: crappy cable
#   Matched span: indie movies
#   Matched span: anatomical difference
#   Matched span: female genitals
#   Matched span: American film
#   Matched span: explicit erotica
#   Matched span: double standard
#   Matched span: depressing ability
#
#
# Review 3:
#   Matched span: IMPORTANT issues
#   Matched span: discernable motive
#   Matched span: new perspectives
#   Matched span: pointless film).<br
#
#
# Review 4:
#   Matched span: strong elements
#   Matched span: realistic acting
#   Matched span: endless stream
#   Matched span: annoying actress
#
#
# Review 5:
#   Matched span: ridiculous film
#   Matched span: umpteen years
#   Matched span: early teen
#   Matched span: local film
#   Matched span: anonymous sands
#   Matched span: repulsive Swedes
#   Matched span: political pretension
#   Matched span: simulated sex
#   Matched span: historic artifact
#   Matched span: boring pseudo
#   Matched span: political spewings
#   Matched span: new generation
#   Matched span: naughty sex
#
#
# Review 6:
#   Matched span: unwatchable trash
#   Matched span: worst kind
#   Matched span: controversial politics
#   Matched span: high school
#   Matched span: worst sense
#   Matched span: harsh grainy
#   Matched span: wrong angle
#
#
# Review 7:
#   Matched span: many mistakes
#   Matched span: early years
#   Matched span: later years
#   Matched span: whole list
#   Matched span: factual errors
#   Matched span: inimitable people
#   Matched span: many mistakes
